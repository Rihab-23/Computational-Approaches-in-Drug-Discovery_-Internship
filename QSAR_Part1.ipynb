# %% [markdown]
# PART1_QSAR_EGFR

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data_EGFR"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data_EGFR’: File exists

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.1.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.5.1)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.0 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.7 MB/s eta 0:00:00
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 5.5 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.3.0 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search("EGFR")
targets = pd.DataFrame.from_dict(target_query)
targets.head()
# Out:
#   cross_references      organism  \
# 0               []  Mus musculus
# 1               []  Homo sapiens
# 2               []  Homo sapiens
# 3               []  Homo sapiens
# 4               []  Homo sapiens
#
#                                            pref_name  score  \
# 0                   Epidermal growth factor receptor   16.0
# 1                                        EGFR/PPP1CA   16.0
# 2                                          CCN2-EGFR   16.0
# 3                   Epidermal growth factor receptor   12.0
# 4  Protein cereblon/Epidermal growth factor receptor   11.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL3608
# 1               False    CHEMBL4523747
# 2               False    CHEMBL5465557
# 3               False        CHEMBL203
# 4               False    CHEMBL4523680
#
#                                    target_components  \
# 0  [{'accession': 'Q01279', 'component_descriptio...
# 1  [{'accession': 'P00533', 'component_descriptio...
# 2  [{'accession': 'P00533', 'component_descriptio...
# 3  [{'accession': 'P00533', 'component_descriptio...
# 4  [{'accession': 'P00533', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN   10090
# 1  PROTEIN-PROTEIN INTERACTION    9606
# 2  PROTEIN-PROTEIN INTERACTION    9606
# 3               SINGLE PROTEIN    9606
# 4  PROTEIN-PROTEIN INTERACTION    9606

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL3608'

# %%
activity = new_client.activity
results = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df1 = pd.DataFrame.from_dict(results)
df1.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       110221                  []
# 1        None             None       113118                  []
# 2        None             None       119387                  []
# 3        None             None       133319                  []
# 4        None             None       193384                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL675511  Inhibition of epidermal growth factor receptor...
# 1    CHEMBL675511  Inhibition of epidermal growth factor receptor...
# 2    CHEMBL675511  Inhibition of epidermal growth factor receptor...
# 3    CHEMBL675511  Inhibition of epidermal growth factor receptor...
# 4    CHEMBL675513  Inhibition of epidermal growth factor receptor...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                  target_pref_name target_tax_id text_value  \
# 0    Mus musculus  Epidermal growth factor receptor         10090       None
# 1    Mus musculus  Epidermal growth factor receptor         10090       None
# 2    Mus musculus  Epidermal growth factor receptor         10090       None
# 3    Mus musculus  Epidermal growth factor receptor         10090       None
# 4    Mus musculus  Epidermal growth factor receptor         10090       None
#
#    toid  type units    uo_units upper_value  value
# 0  None  IC50    uM  UO_0000065        None  100.0
# 1  None  IC50    uM  UO_0000065        None  100.0
# 2  None  IC50    uM  UO_0000065        None  100.0
# 3  None  IC50    uM  UO_0000065        None   25.0
# 4  None  IC50    uM  UO_0000065        None   0.07
#
# [5 rows x 46 columns]

# %%
df1.shape[0]
# Out:
# 97

# %%
df1.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df1.to_csv('bioactivity_raw_data.csv', index=False)

# %%
! cp bioactivity_raw_data.csv "/content/gdrive/My Drive/Colab Notebooks/data_EGFR"
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data_EGFR"
! head bioactivity_raw_data.csv
# Out:
# total 64
# -rw------- 1 root root  7306 Jan 26 23:30 bioactivity_preprocessed_data.csv
# -rw------- 1 root root 57149 Jan 27 19:31 bioactivity_raw_data.csv
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,110221,[],CHEMBL675511,Inhibition of epidermal growth factor receptor (EGFR-mediated tyrosine autophosphorylation in mouse fibroblasts.,B,,,BAO_0000190,BAO_0000357,single protein format,COc1cccc2c(C(=O)Nc3ccccc3)c(SSc3c(C(=O)Nc4ccccc4)c4cccc(OC)c4n3C)n(C)c12,,,CHEMBL1127560,J Med Chem,1994,,CHEMBL292323,,CHEMBL292323,,0,http://www.openphacts.org/units/Nanomolar,109049,>,1,1,>,,IC50,nM,,100000.0,CHEMBL3608,Mus musculus,Epidermal growth factor receptor,10090,,,IC50,uM,UO_0000065,,100.0
# ,,113118,[],CHEMBL675511,Inhibition of epidermal growth factor receptor (EGFR-mediated tyrosine autophosphorylation in mouse fibroblasts.,B,,,BAO_0000190,BAO_0000357,single protein format,Cn1c(SSc2c(C(=O)Nc3ccccc3)c3ccccc3n2C)c(C(=O)Nc2ccccc2)c2ccccc21,,,CHEMBL1127560,J Med Chem,1994,,CHEMBL304414,,CHEMBL304414,,0,http://www.openphacts.org/units/Nanomolar,109028,>,1,1,>,,IC50,nM,,100000.0,CHEMBL3608,Mus musculus,Epidermal growth factor receptor,10090,,,IC50,uM,UO_0000065,,100.0
# ,,119387,[],CHEMBL675511,Inhibition of epidermal growth factor receptor (EGFR-mediated tyrosine autophosphorylation in mouse fibroblasts.,B,,,BAO_0000190,BAO_0000357,single protein format,CN1C(=S)C(C(=O)Nc2ccccc2)c2ccccc21,,,CHEMBL1127560,J Med Chem,1994,,CHEMBL62176,,CHEMBL62176,,0,http://www.openphacts.org/units/Nanomolar,109045,>,1,1,>,,IC50,nM,,100000.0,CHEMBL3608,Mus musculus,Epidermal growth factor receptor,10090,,,IC50,uM,UO_0000065,,100.0
# ,,133319,[],CHEMBL675511,Inhibition of epidermal growth factor receptor (EGFR-mediated tyrosine autophosphorylation in mouse fibroblasts.,B,,,BAO_0000190,BAO_0000357,single protein format,Cn1c(SSc2c(C(=O)Nc3ccccc3)c3cccnc3n2C)c(C(=O)Nc2ccccc2)c2cccnc21,,,CHEMBL1127560,J Med Chem,1994,,CHEMBL62701,,CHEMBL62701,,0,http://www.openphacts.org/units/Nanomolar,109046,>,1,1,>,,IC50,nM,,25000.0,CHEMBL3608,Mus musculus,Epidermal growth factor receptor,10090,,,IC50,uM,UO_0000065,,25.0
# ,,193384,[],CHEMBL675513,Inhibition of epidermal growth factor receptor tyrosine kinase (EGFR TK),B,,,BAO_0000190,BAO_0000357,single protein format,C/N=N/Nc1ccc2ncnc(Nc3cccc(Br)c3)c2c1,,,CHEMBL1145931,J Med Chem,2003,"{'bei': '20.03', 'le': '0.44', 'lle': '2.61', 'sei': '9.60'}",CHEMBL137617,,CHEMBL137617,7.16,0,http://www.openphacts.org/units/Nanomolar,297951,=,1,1,=,,IC50,nM,,70.0,CHEMBL3608,Mus musculus,Epidermal growth factor receptor,10090,,,IC50,uM,UO_0000065,,0.07
# ,,206505,[],CHEMBL675513,Inhibition of epidermal growth factor receptor tyrosine kinase (EGFR TK),B,,,BAO_0000190,BAO_0000357,single protein format,CC(=O)N(C)/N=N/c1ccc2ncnc(Nc3cccc(C)c3)c2c1,,,CHEMBL1145931,J Med Chem,2003,"{'bei': '18.66', 'le': '0.34', 'lle': '2.08', 'sei': '7.53'}",CHEMBL153577,,CHEMBL153577,6.24,0,http://www.openphacts.org/units/Nanomolar,297945,=,1,1,=,,IC50,nM,,578.0,CHEMBL3608,Mus musculus,Epidermal growth factor receptor,10090,,,IC50,uM,UO_0000065,,0.578
# ,,208867,[],CHEMBL675513,Inhibition of epidermal growth factor receptor tyrosine kinase (EGFR TK),B,,,BAO_0000190,BAO_0000357,single protein format,CN(CO)/N=N/c1ccc2ncnc(Nc3cccc(Br)c3)c2c1,,,CHEMBL1145931,J Med Chem,2003,"{'bei': '17.97', 'le': '0.40', 'lle': '2.94', 'sei': '8.09'}",CHEMBL152448,,CHEMBL152448,6.96,0,http://www.openphacts.org/units/Nanomolar,297952,=,1,1,=,,IC50,nM,,110.0,CHEMBL3608,Mus musculus,Epidermal growth factor receptor,10090,,,IC50,uM,UO_0000065,,0.11
# ,,214669,[],CHEMBL675513,Inhibition of epidermal growth factor receptor tyrosine kinase (EGFR TK),B,,,BAO_0000190,BAO_0000357,single protein format,C/N=N/Nc1ccc2ncnc(Nc3cccc(C)c3)c2c1,,,CHEMBL1145931,J Med Chem,2003,"{'bei': '22.91', 'le': '0.42', 'lle': '2.61', 'sei': '8.98'}",CHEMBL137189,,CHEMBL137189,6.70,0,http://www.openphacts.org/units/Nanomolar,297944,=,1,1,=,,IC50,nM,,200.0,CHEMBL3608,Mus musculus,Epidermal growth factor receptor,10090,,,IC50,uM,UO_0000065,,0.2
# ,,218313,[],CHEMBL675513,Inhibition of epidermal growth factor receptor tyrosine kinase (EGFR TK),B,,,BAO_0000190,BAO_0000357,single protein format,Nc1ccc2ncnc(Nc3cccc(Br)c3)c2c1,,,CHEMBL1145931,J Med Chem,2003,"{'bei': '23.47', 'le': '0.53', 'lle': '3.68', 'sei': '11.59'}",CHEMBL52765,,CHEMBL52765,7.40,0,http://www.openphacts.org/units/Nanomolar,297946,=,1,1,=,,IC50,nM,,40.0,CHEMBL3608,Mus musculus,Epidermal growth factor receptor,10090,,,IC50,uM,UO_0000065,,0.04

# %%
from google.colab import files
files.download('bioactivity_raw_data.csv')

# %%
df1["standard_type"].isna().sum()
# Out:
# np.int64(0)

# %%
df2 = df1[df1["standard_value"].notna()]
df2.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       110221                  []
# 1        None             None       113118                  []
# 2        None             None       119387                  []
# 3        None             None       133319                  []
# 4        None             None       193384                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL675511  Inhibition of epidermal growth factor receptor...
# 1    CHEMBL675511  Inhibition of epidermal growth factor receptor...
# 2    CHEMBL675511  Inhibition of epidermal growth factor receptor...
# 3    CHEMBL675511  Inhibition of epidermal growth factor receptor...
# 4    CHEMBL675513  Inhibition of epidermal growth factor receptor...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                  target_pref_name target_tax_id text_value  \
# 0    Mus musculus  Epidermal growth factor receptor         10090       None
# 1    Mus musculus  Epidermal growth factor receptor         10090       None
# 2    Mus musculus  Epidermal growth factor receptor         10090       None
# 3    Mus musculus  Epidermal growth factor receptor         10090       None
# 4    Mus musculus  Epidermal growth factor receptor         10090       None
#
#    toid  type units    uo_units upper_value  value
# 0  None  IC50    uM  UO_0000065        None  100.0
# 1  None  IC50    uM  UO_0000065        None  100.0
# 2  None  IC50    uM  UO_0000065        None  100.0
# 3  None  IC50    uM  UO_0000065        None   25.0
# 4  None  IC50    uM  UO_0000065        None   0.07
#
# [5 rows x 46 columns]

# %%
bioactivity_class = []
for value in df2.standard_value:
    value = float(value)
    if value >= 10000:
        bioactivity_class.append("inactive")
    elif value <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %%
molecule_ids = df2.molecule_chembl_id.tolist()
canonical_smiles = df2.canonical_smiles.tolist()
standard_values = df2.standard_value.tolist()

# %%
data = list(zip(
    molecule_ids,
    canonical_smiles,
    standard_values,
        bioactivity_class,
))

# %%
df3 = pd.DataFrame(
    data,
    columns=[
        "molecule_chembl_id",
        "canonical_smiles",
        "standard_value",
        "bioactivity_class",
    ]
)
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL292323  COc1cccc2c(C(=O)Nc3ccccc3)c(SSc3c(C(=O)Nc4cccc...
# 1       CHEMBL304414  Cn1c(SSc2c(C(=O)Nc3ccccc3)c3ccccc3n2C)c(C(=O)N...
# 2        CHEMBL62176                 CN1C(=S)C(C(=O)Nc2ccccc2)c2ccccc21
# 3        CHEMBL62701  Cn1c(SSc2c(C(=O)Nc3ccccc3)c3cccnc3n2C)c(C(=O)N...
# 4       CHEMBL137617               C/N=N/Nc1ccc2ncnc(Nc3cccc(Br)c3)c2c1
#
#   standard_value bioactivity_class
# 0       100000.0          inactive
# 1       100000.0          inactive
# 2       100000.0          inactive
# 3        25000.0          inactive
# 4           70.0            active

# %%
df3 = df3.dropna(subset=["canonical_smiles"])
df3 = df3[df3["canonical_smiles"].str.lower() != "none"]
df3 = df3[df3["canonical_smiles"].str.strip() != ""]
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL292323  COc1cccc2c(C(=O)Nc3ccccc3)c(SSc3c(C(=O)Nc4cccc...
# 1       CHEMBL304414  Cn1c(SSc2c(C(=O)Nc3ccccc3)c3ccccc3n2C)c(C(=O)N...
# 2        CHEMBL62176                 CN1C(=S)C(C(=O)Nc2ccccc2)c2ccccc21
# 3        CHEMBL62701  Cn1c(SSc2c(C(=O)Nc3ccccc3)c3cccnc3n2C)c(C(=O)N...
# 4       CHEMBL137617               C/N=N/Nc1ccc2ncnc(Nc3cccc(Br)c3)c2c1
#
#   standard_value bioactivity_class
# 0       100000.0          inactive
# 1       100000.0          inactive
# 2       100000.0          inactive
# 3        25000.0          inactive
# 4           70.0            active

# %%
df3.to_csv("bioactivity_preprocessed_data.csv", index=False)

# !cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data_EGFR"
# !ls "/content/gdrive/My Drive/Colab Notebooks/data_EGFR"
# Out:
# bioactivity_preprocessed_data.csv  bioactivity_raw_data.csv

# %%
from google.colab import files
files.download('bioactivity_preprocessed_data.csv')
